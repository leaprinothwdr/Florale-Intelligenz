# %%
import pandas as pd
from pandas import read_csv

import seaborn as sb
import matplotlib.pyplot as plt
import scipy

# %%
df = read_csv("iris.csv", index_col=0)

# %%
df
# Out:
#          sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# instant
# 0                    5.1             3.5              1.4             0.2
# 1                    4.9             3.0              1.4             0.2
# 2                    4.7             3.2              1.3             0.2
# 3                    4.6             3.1              1.5             0.2
# 4                    5.0             3.6              1.4             0.2
# ...                  ...             ...              ...             ...
# 145                  6.7             3.0              5.2             2.3
# 146                  6.3             2.5              5.0             1.9
# 147                  6.5             3.0              5.2             2.0
# 148                  6.2             3.4              5.4             2.3
# 149                  5.9             3.0              5.1             1.8
#
#            species
# instant
# 0           setosa
# 1           setosa
# ...

# %% [markdown]
# # Explorative Datenanalyse

# %%
#Geeignete, statistische Gesamtauswertung aller nummerischen Features
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      150.000000
# mean          5.843333        3.057333         3.758000        1.199333
# std           0.828066        0.435866         1.765298        0.762238
# min           4.300000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
#Auswertung Feature sepal_length_cm
plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
sb.histplot(y=df["sepal_length_cm"], kde=True)
plt.title("Verteilung der Sepal-Länge")

plt.subplot(1,2,2)
sb.boxplot(y=df["sepal_length_cm"])
plt.title("Boxplot der Sepal-Länge")

plt.show()

# %%
#Gemeinsame Bewegung auswerten
sb.scatterplot(data=df, x="sepal_length_cm", y="petal_length_cm", hue="species")
plt.title("Zusammenhang zwischen Sepal- und Petal-Länge")
plt.show()

# %%
#Korrelationsanalyse

#import numpy as np

corr = df.drop(columns=["species"]).corr(numeric_only=True)

plt.figure(figsize=(8, 6))
sb.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Korrelationsmatrix")
plt.show()

# %%
#Pairplot
sb.pairplot(df, hue='species')
plt.show()

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# # Supervised Learning
