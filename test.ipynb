# %%
import pandas as pd
from pandas import read_csv

import seaborn as sb
import matplotlib.pyplot as plt
import scipy

# %%
df = read_csv("iris.csv", index_col=0)

# %%
df
# Out:
#          sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# instant
# 0                    5.1             3.5              1.4             0.2
# 1                    4.9             3.0              1.4             0.2
# 2                    4.7             3.2              1.3             0.2
# 3                    4.6             3.1              1.5             0.2
# 4                    5.0             3.6              1.4             0.2
# ...                  ...             ...              ...             ...
# 145                  6.7             3.0              5.2             2.3
# 146                  6.3             2.5              5.0             1.9
# 147                  6.5             3.0              5.2             2.0
# 148                  6.2             3.4              5.4             2.3
# 149                  5.9             3.0              5.1             1.8
#
#            species
# instant
# 0           setosa
# 1           setosa
# 2           setosa
# 3           setosa
# 4           setosa
# ...            ...
# 145      virginica
# 146      virginica
# 147      virginica
# 148      virginica
# 149      virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Explorative Datenanalyse

# %%
#Geeignete, statistische Gesamtauswertung aller nummerischen Features
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      150.000000
# mean          5.843333        3.057333         3.758000        1.199333
# std           0.828066        0.435866         1.765298        0.762238
# min           4.300000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
#Auswertung Feature sepal_length_cm
plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
sb.histplot(y=df["sepal_length_cm"], kde=True)
plt.title("Verteilung der Sepal-Länge")

plt.subplot(1,2,2)
sb.boxplot(y=df["sepal_length_cm"])
plt.title("Boxplot der Sepal-Länge")

plt.show()

# %%
#Gemeinsame Bewegung auswerten
sb.scatterplot(data=df, x="sepal_length_cm", y="petal_length_cm", hue="species")
plt.title("Zusammenhang zwischen Sepal- und Petal-Länge")
plt.show()

# %%
#Korrelationsanalyse

import numpy as np

corr = df.drop(columns=[""]).corr(numeric_only=True)

plt.figure(figsize=(8, 6))
sb.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Korrelationsmatrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 5
#       1 #Korrelationsanalyse
#       3 import numpy as np
# ----> 5 corr = df.drop(columns=['instant']).corr(numeric_only=True)
#       7 plt.figure(figsize=(8, 6))
#       8 sb.heatmap(corr, annot=True, cmap='coolwarm')
#
# File ~/Documents/GitHub/Florale-Intelligenz/petalenv/lib/python3.13/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/Documents/GitHub/Florale-Intelligenz/petalenv/lib/python3.13/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/Documents/GitHub/Florale-Intelligenz/petalenv/lib/python3.13/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/Documents/GitHub/Florale-Intelligenz/petalenv/lib/python3.13/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['instant'] not found in axis"

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# # Supervised Learning
